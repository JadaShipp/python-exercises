# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pydataset
from pydataset import data

import seaborn as sns
import env

# %%
#tips = sns.load_dataset('tips')

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
# #### What does the distribution of petal lengths look like?

# %%
#sns.distplot(tips.total_bill)

sns.distplot(iris.petal_length)

# %% [markdown]
# #### Is there a correlation between petal length and petal width?

# %%
#sns.relplot(x='total_bill', y='tip', data=tips)

sns.relplot(x='petal_length',y='petal_width', data=iris)

# %% [markdown]
# #### Would it be reasonable to predict species based on sepal width and sepal length?

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %%
df = iris[['sepal_width','sepal_length','species']]

# %%
df
# Out:
#      sepal_width  sepal_length     species
# 0            3.5           5.1      setosa
# 1            3.0           4.9      setosa
# 2            3.2           4.7      setosa
# 3            3.1           4.6      setosa
# 4            3.6           5.0      setosa
# 5            3.9           5.4      setosa
# 6            3.4           4.6      setosa
# 7            3.4           5.0      setosa
# 8            2.9           4.4      setosa
# 9            3.1           4.9      setosa
# 10           3.7           5.4      setosa
# 11           3.4           4.8      setosa
# 12           3.0           4.8      setosa
# 13           3.0           4.3      setosa
# 14           4.0           5.8      setosa
# 15           4.4           5.7      setosa
# 16           3.9           5.4      setosa
# 17           3.5           5.1      setosa
# 18           3.8           5.7      setosa
# 19           3.8           5.1      setosa
# 20           3.4           5.4      setosa
# ...

# %%
 df.groupby('species').sepal_width.value_counts()
# Out:
# species     sepal_width
# setosa      3.4             9
#             3.0             6
#             3.5             6
#             3.2             5
#             3.1             4
#             3.8             4
#             3.6             3
#             3.7             3
#             3.3             2
#             3.9             2
#             2.3             1
#             2.9             1
#             4.0             1
#             4.1             1
#             4.2             1
#             4.4             1
# versicolor  3.0             8
#             2.9             7
#             2.8             6
#             2.7             5
#             2.5             4
#             2.3             3
#             2.4             3
#             2.6             3
#             3.1             3
#             3.2             3
#             2.2             2
#             2.0             1
#             3.3             1
#             3.4             1
# ...

# %%
iris.groupby('petal_width').species.value_counts()
# Out:
# petal_width  species
# 0.1          setosa         5
# 0.2          setosa        29
# 0.3          setosa         7
# 0.4          setosa         7
# 0.5          setosa         1
# 0.6          setosa         1
# 1.0          versicolor     7
# 1.1          versicolor     3
# 1.2          versicolor     5
# 1.3          versicolor    13
# 1.4          versicolor     7
#              virginica      1
# 1.5          versicolor    10
#              virginica      2
# 1.6          versicolor     3
#              virginica      1
# 1.7          versicolor     1
#              virginica      1
# 1.8          virginica     11
#              versicolor     1
# 1.9          virginica      5
# 2.0          virginica      6
# 2.1          virginica      6
# 2.2          virginica      3
# 2.3          virginica      8
# 2.4          virginica      3
# 2.5          virginica      3
# Name: species, dtype: int64

# %%
sns.relplot(x='species', y='petal_width', data=iris)

# %% [markdown]
# ### import seaborn as sns
# ### import pydataset
# ### iris = sns.load_dataset('iris') # this one is actually in both seaborn and pydataset
# ### swiss = pydataset.data('swiss')
# ### insect_sprays = pydataset.data('InsectSprays')
# ### sleep_study = pydataset.data('sleepstudy')

# %%
insect_sprays = pydataset.data('InsectSprays')

# %%
insect_sprays
# Out:
#     count spray
# 1      10     A
# 2       7     A
# 3      20     A
# 4      14     A
# 5      14     A
# 6      12     A
# 7      10     A
# 8      23     A
# 9      17     A
# 10     20     A
# 11     14     A
# 12     13     A
# 13     11     B
# 14     17     B
# 15     21     B
# 16     11     B
# 17     16     B
# 18     14     B
# 19     17     B
# 20     17     B
# 21     19     B
# 22     21     B
# 23      7     B
# 24     13     B
# 25      0     C
# 26      1     C
# 27      7     C
# 28      2     C
# 29      3     C
# 30      1     C
# 31      2     C
# 32      1     C
# 33      3     C
# 34      0     C
# 35      1     C
# 36      4     C
# 37      3     D
# 38      5     D
# 39     12     D
# 40      6     D
# 41      4     D
# 42      3     D
# 43      5     D
# 44      5     D
# 45      5     D
# 46      5     D
# 47      2     D
# 48      4     D
# 49      3     E
# 50      5     E
# 51      3     E
# 52      5     E
# 53      3     E
# 54      6     E
# ...

# %%
data('InsectSprays', show_doc=True)

#data('mpg', show_doc=True)
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
# ...

# %% [markdown]
# #### Load the InsectSprays dataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
#df.rename(columns={'name': 'student'})

insect_sprays.rename(columns={'count':'number_of_insects'})
# Out:
#     number_of_insects spray
# 1                  10     A
# 2                   7     A
# 3                  20     A
# 4                  14     A
# 5                  14     A
# 6                  12     A
# 7                  10     A
# 8                  23     A
# 9                  17     A
# 10                 20     A
# 11                 14     A
# 12                 13     A
# 13                 11     B
# 14                 17     B
# 15                 21     B
# 16                 11     B
# 17                 16     B
# 18                 14     B
# 19                 17     B
# 20                 17     B
# 21                 19     B
# 22                 21     B
# 23                  7     B
# 24                 13     B
# 25                  0     C
# 26                  1     C
# 27                  7     C
# 28                  2     C
# 29                  3     C
# 30                  1     C
# 31                  2     C
# 32                  1     C
# ...

# %%
insect_sprays.spray.value_counts()
# Out:
# B    12
# F    12
# D    12
# E    12
# A    12
# C    12
# Name: spray, dtype: int64

# %%
insect_sprays.groupby('spray').mean()
# Out:
#            count
# spray
# A      14.500000
# B      15.333333
# C       2.083333
# D       4.916667
# E       3.500000
# F      16.666667

# %%
sns.boxplot(data=insect_sprays, x='count')

# %%
sns.boxplot(data=insect_sprays, y='count', x='spray')

# %% [markdown]
# #### Load the swiss dataset and read it's documentation. Create visualizations to answer the following questions:

# %%
swiss = pydataset.data('swiss')

# %%
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
data('swiss', show_doc=True)
# Out:
# swiss
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Swiss Fertility and Socioeconomic Indicators (1888) Data
#
# ### Description
#
# Standardized fertility measure and socio-economic indicators for each of 47
# French-speaking provinces of Switzerland at about 1888.
#
# ### Usage
#
#     data(swiss)
#
# ### Format
#
# A data frame with 47 observations on 6 variables, each of which is in percent,
# i.e., in [0,100].
#
# [,1] Fertility Ig, "common standardized fertility measure" [,2] Agriculture
# [,3] Examination nation [,4] Education [,5] Catholic [,6] Infant.Mortality
# live births who live less than 1 year.
#
# All variables but 'Fert' give proportions of the population.
#
# ### Source
#
# Project "16P5", pages 549-551 in
#
# Mosteller, F. and Tukey, J. W. (1977) “Data Analysis and Regression: A Second
# Course in Statistics”. Addison-Wesley, Reading Mass.
#
# ...

# %%
swiss['is_catholic']=swiss.Catholic>50

# %% [markdown]
# #### Does whether or not a province is Catholic influence fertility?

# %%
df = swiss[['Fertility','is_catholic']]

# %%
df.head()
# Out:
#               Fertility  is_catholic
# Courtelary         80.2        False
# Delemont           83.1         True
# Franches-Mnt       92.5         True
# Moutier            85.8        False
# Neuveville         76.9        False

# %%
fertility_influence = df.groupby('is_catholic').Fertility.mean()

# %%
ax = fertility_influence.plot.bar(x='is_catholic',y='Fertility', rot = 0)
# ax = df.plot.bar(x='lab', y='val', rot=0)

# %% [markdown]
# #### What measure correlates most strongly with fertility?

# %%
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Delemont                  22.2         True
# Franches-Mnt              20.2         True
# Moutier                   20.3        False
# Neuveville                20.6        False

# %%
# swiss['is_catholic']=swiss.Catholic>50

# %%
swiss.is_catholic = swiss.is_catholic.astype(int)

# %%
sns.pairplot(swiss)

# %% [markdown]
# #### Using the chipotle dataset from the previous exercise, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
def get_db_url(dbname) -> str:
    url = 'mysql+pymysql://{}:{}@{}/{}'
    return url.format(env.user, env.password, env.host, dbname)

# %%
query = '''
SELECT *
FROM orders
'''

orders = pd.read_sql(query, get_db_url('chipotle'))

# %%
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
four_most_popular_orders = orders.groupby('item_name').quantity.sum().nlargest(4)

# %%
bar_chart = four_most_popular_orders.plot.bar(x='item_name',y='quantity')
